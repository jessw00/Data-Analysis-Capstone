# %%
import csv
import os
from os import path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Define relative filepath in a subdirectory
file_path = "data/taylor_album_songs.csv"

# Read file and print dataframe
data_taylor_album_songs = pd.read_csv(file_path)
print(data_taylor_album_songs)

# Print column names and data types
print("Column names:", data_taylor_album_songs.columns)
print("Data types:")
print(data_taylor_album_songs.dtypes)

# Define relative filepath in a subdirectory
file_path = "data/taylor_lyrics.csv"

# Read file and print dataframe
data_taylor_lyrics = pd.read_csv(file_path)
print(data_taylor_lyrics)

# Print column names and data types
print("Column names:", data_taylor_lyrics.columns)
print("Data types:")
print(data_taylor_lyrics.dtypes)
# Out:
#        album_name     ep album_release  track_number  \
# 0    Taylor Swift  False    2006-10-24             1
# 1    Taylor Swift  False    2006-10-24             2
# 2    Taylor Swift  False    2006-10-24             3
# 3    Taylor Swift  False    2006-10-24             4
# 4    Taylor Swift  False    2006-10-24             5
# ..            ...    ...           ...           ...
# 189     Midnights  False    2022-10-21            19
# 190     Midnights  False    2022-10-21            20
# 191     Midnights  False    2022-10-21            14
# 192     Midnights  False    2022-10-21            15
# 193     Midnights  False    2022-10-21            16
#
#                                   track_name        artist featuring  \
# 0                                 Tim McGraw  Taylor Swift       NaN
# 1                            Picture To Burn  Taylor Swift       NaN
# 2                     Teardrops On My Guitar  Taylor Swift       NaN
# 3                      A Place In This World  Taylor Swift       NaN
# 4                                Cold As You  Taylor Swift       NaN
# ..                                       ...           ...       ...
# 189            Would've, Could've, Should've  Taylor Swift       NaN
# 190                              Dear Reader  Taylor Swift       NaN
# 191                           Hits Different           NaN       NaN
# 192  You're On Your Own, Kid (Strings Remix)           NaN       NaN
# 193              Sweet Nothing (Piano Remix)           NaN       NaN
#
#      bonus_track promotional_release single_release  ... liveness  valence  \
# 0          False                 NaN     2006-06-19  ...   0.1210    0.425
# 1          False                 NaN     2008-02-03  ...   0.0962    0.821
# 2          False                 NaN     2007-02-19  ...   0.1190    0.289
# 3          False                 NaN            NaN  ...   0.3200    0.428
# 4          False                 NaN            NaN  ...   0.1230    0.261
# ..           ...                 ...            ...  ...      ...      ...
# 189         True                 NaN            NaN  ...   0.1460    0.550
# 190         True                 NaN            NaN  ...   0.1170    0.159
# 191         True                 NaN            NaN  ...      NaN      NaN
# 192         True                 NaN            NaN  ...      NaN      NaN
# 193         True                 NaN            NaN  ...      NaN      NaN
#
#        tempo  time_signature  duration_ms  explicit  key_name  mode_name  \
# 0     76.009             4.0     232107.0     False         C      major
# 1    105.586             4.0     173067.0     False         G      major
# 2     99.953             4.0     203040.0     False        A#      major
# 3    115.028             4.0     199200.0     False         A      major
# 4    175.558             4.0     239013.0     False         F      major
# ..       ...             ...          ...       ...       ...        ...
# 189  157.979             4.0     260362.0     False         G      major
# 190  107.747             4.0     225194.0     False         C      major
# 191      NaN             NaN          NaN       NaN       NaN        NaN
# 192      NaN             NaN          NaN       NaN       NaN        NaN
# 193      NaN             NaN          NaN       NaN       NaN        NaN
#
#      key_mode  lyrics
# 0     C major     NaN
# 1     G major     NaN
# 2    A# major     NaN
# 3     A major     NaN
# 4     F major     NaN
# ..        ...     ...
# 189   G major     NaN
# 190   C major     NaN
# 191       NaN     NaN
# 192       NaN     NaN
# 193       NaN     NaN
#
# [194 rows x 29 columns]
# Column names: Index(['album_name', 'ep', 'album_release', 'track_number', 'track_name',
#        'artist', 'featuring', 'bonus_track', 'promotional_release',
#        'single_release', 'track_release', 'danceability', 'energy', 'key',
#        'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'time_signature', 'duration_ms',
#        'explicit', 'key_name', 'mode_name', 'key_mode', 'lyrics'],
#       dtype='object')
# Data types:
# album_name              object
# ep                        bool
# album_release           object
# track_number             int64
# track_name              object
# artist                  object
# featuring               object
# bonus_track               bool
# promotional_release     object
# single_release          object
# track_release           object
# danceability           float64
# energy                 float64
# key                    float64
# loudness               float64
# mode                   float64
# speechiness            float64
# acousticness           float64
# instrumentalness       float64
# liveness               float64
# valence                float64
# tempo                  float64
# time_signature         float64
# duration_ms            float64
# explicit                object
# key_name                object
# mode_name               object
# key_mode                object
# lyrics                 float64
# dtype: object
#                             Album Release Date  \
# 0           Taylor Swift (Deluxe)   06/11/2007
# 1           Taylor Swift (Deluxe)   06/11/2007
# 2           Taylor Swift (Deluxe)   06/11/2007
# 3           Taylor Swift (Deluxe)   06/11/2007
# 4           Taylor Swift (Deluxe)   06/11/2007
# ..                            ...          ...
# 202  Speak Now (Taylor’s Version)   07/07/2023
# 203  Speak Now (Taylor’s Version)   07/07/2023
# 204  Speak Now (Taylor’s Version)   07/07/2023
# 205  Speak Now (Taylor’s Version)   07/07/2023
# 206  Speak Now (Taylor’s Version)   07/07/2023
#
#                                             Song Title Featured Artists  \
# 0                                           Tim McGraw              NaN
# 1                                      Picture to Burn              NaN
# 2                               Teardrops On My Guitar              NaN
# 3                                A Place In This World              NaN
# 4                                          Cold as You              NaN
# ..                                                 ...              ...
# 202  I Can See You (Taylor’s Version) [From The Vault]              NaN
# 203  Castles Crumbling (Taylor’s Version) [From The...  Hayley Williams
# 204    Foolish One (Taylor’s Version) [From The Vault]              NaN
# 205       Timeless (Taylor’s Version) [From The Vault]              NaN
# 206            Speak Now (Taylor’s Version) [Prologue]              NaN
#
#                                                 Lyrics
# 0    He said the way my blue eyes shined Put those ...
# 1    State the obvious I didn t get my perfect fant...
# 2    Drew looks at me I fake a smile so he won t se...
# 3    I don t know what I want so don t ask me Cause...
# 4    You have a way of coming easily to me And when...
# ..                                                 ...
# 202  I I I I You brush past me in the hallway And y...
# 203  Once I had an empire Once I had an empire Once...
# 204  My cards are on the table yours are in your ha...
# 205  Down the block there s an antique shop And som...
# 206  PrologueWhen I think back on the Speak Now alb...
#
# [207 rows x 5 columns]
# Column names: Index(['Album', 'Release Date', 'Song Title', 'Featured Artists', 'Lyrics'], dtype='object')
# Data types:
# Album               object
# Release Date        object
# Song Title          object
# Featured Artists    object
# Lyrics              object
# dtype: object
